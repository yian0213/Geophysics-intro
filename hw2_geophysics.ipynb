# %% [markdown]
# <a href="https://colab.research.google.com/github/yian0213/Geophysics-intro/blob/main/hw2_geophysics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import importlib.util
import subprocess
import sys

# 在子程序檢查，避免安裝前先載入目前 kernel 的動態函式庫
check_code = """
import pygmt, pandas
import shutil
from pygmt.clib import Session
assert pygmt.__version__.lstrip('v').startswith('0.17.')
assert shutil.which('gs')
with Session() as session:
    assert session.info['version'].startswith('6.5.')
"""
try:
    ENV_READY = subprocess.run(
        [sys.executable, "-c", check_code], capture_output=True, timeout=30
    ).returncode == 0
except subprocess.TimeoutExpired:
    ENV_READY = False

IN_COLAB = importlib.util.find_spec("google.colab") is not None if importlib.util.find_spec("google") else False
if ENV_READY:
    print("環境已可用，跳過安裝。")
elif IN_COLAB:
    print("步驟 1/2：安裝 Conda（約 1 分鐘）。完成後 Colab 會自動重啟執行環境，等重新連線再執行下一格。", flush=True)
    subprocess.check_call([sys.executable, "-m", "pip", "install", "-q", "condacolab==0.1.13"])
    import condacolab
    condacolab.install()
else:
    print("本機模式：使用目前 Python 環境。")
# Out:
# 步驟 1/2：安裝 Conda（約 1 分鐘）。完成後 Colab 會自動重啟執行環境，等重新連線再執行下一格。
#
# 📢 Announcement 📢
# condacolab==0.2 will be released soon! Try it with:
#
#     !pip install -q https://github.com/conda-incubator/condacolab/archive/main.zip
#     import condacolab
#     condacolab.install()
#
# 0.2.x introduces a new installation method based on Pixi, with customizable Python versions.
# This may be breaking for your workflow. If that's the case, please report it at
# https://github.com/conda-incubator/condacolab and pin your `pip install` command to
# condacolab==0.1 as a workaround.
#
# ⏬ Downloading https://github.com/conda-forge/miniforge/releases/download/26.3.2-3/Miniforge3-26.3.2-3-Linux-x86_64.sh...
# 📦 Installing...
# 📌 Adjusting configuration...
# 🩹 Patching environment...
# ⏲ Done in 0:00:11
# 🔁 Restarting kernel...

# %%
# !git clone https://github.com/cwbdayi638/pygmt-map-lab.git
# Out:
# Cloning into 'pygmt-map-lab'...
# remote: Enumerating objects: 558, done.
# remote: Counting objects: 100% (11/11), done.
# remote: Compressing objects: 100% (7/7), done.
# remote: Total 558 (delta 8), reused 4 (delta 4), pack-reused 547 (from 1)
# Receiving objects: 100% (558/558), 16.08 MiB | 23.76 MiB/s, done.
# Resolving deltas: 100% (351/351), done.

# %%
import sys
# !mamba install pygmt==0.17.0 gmt=6.5.0 -c conda-forge -c defaults --yes
# %run /content/pygmt-map-lab/examples/02_region_map_section.py
# Out:
# warning  libmamba 'repo.anaconda.com', a commercial channel hosted by Anaconda.com, is used.
#
# warning  libmamba Please make sure you understand Anaconda Terms of Services.
#
# warning  libmamba See: https://legal.anaconda.com/policies/en/
# [+] 0.0s
# [+] 0.1s
# pkgs/r/linux-64 (c..  ⣾  [+] 0.0s
# [+] 0.1s
# conda-forge/linux-64  ⣾
# conda-forge/noarch    ⣾
# pkgs/main/linux-64    ⣾
# pkgs/main/noarch      ⣾
# pkgs/r/linux-64       ⣾  [+] 0.2s
# conda-forge/linux-64   4%
# conda-forge/noarch     1%
# pkgs/main/linux-64     5%
# pkgs/main/noarch      57%
# pkgs/r/linux-64       43%pkgs/main/noarch
# pkgs/r/linux-64
# [+] 0.3s
# conda-forge/linux-64   5%
# conda-forge/noarch     5%
# pkgs/main/linux-64     9%
# pkgs/r/noarch         ⣾  [+] 0.4s
# conda-forge/linux-64   6%
# conda-forge/noarch     6%
# pkgs/main/linux-64    16%
# pkgs/r/noarch         25%[+] 0.5s
# conda-forge/linux-64   8%
# conda-forge/noarch    10%
# pkgs/main/linux-64    24%
# pkgs/r/noarch         78%pkgs/r/noarch
# [+] 0.6s
# conda-forge/linux-64   8%
# conda-forge/noarch    11%
# pkgs/main/linux-64    27%[+] 0.7s
# conda-forge/linux-64  10%
# conda-forge/noarch    13%
# pkgs/main/linux-64    32%[+] 0.8s
# conda-forge/linux-64  11%
# conda-forge/noarch    15%
# pkgs/main/linux-64    36%[+] 0.9s
# conda-forge/linux-64  12%
# conda-forge/noarch    19%
# pkgs/main/linux-64    45%[+] 1.0s
# conda-forge/linux-64  14%
# conda-forge/noarch    22%
# pkgs/main/linux-64    49%[+] 1.1s
# conda-forge/linux-64  16%
# conda-forge/noarch    27%
# pkgs/main/linux-64    60%[+] 1.2s
# conda-forge/linux-64  19%
# conda-forge/noarch    30%
# pkgs/main/linux-64    73%[+] 1.3s
# conda-forge/linux-64  20%
# conda-forge/noarch    36%
# pkgs/main/linux-64    80%[+] 1.4s
# conda-forge/linux-64  23%
# conda-forge/noarch    41%
# pkgs/main/linux-64    91%pkgs/main/linux-64
# [+] 1.5s
# conda-forge/linux-64  25%
# conda-forge/noarch    45%[+] 1.6s
# conda-forge/linux-64  29%
# conda-forge/noarch    52%[+] 1.7s
# conda-forge/linux-64  33%
# conda-forge/noarch    61%[+] 1.8s
# conda-forge/linux-64  35%
# conda-forge/noarch    65%[+] 1.9s
# conda-forge/linux-64  40%
# conda-forge/noarch    74%[+] 2.0s
# conda-forge/linux-64  43%
# conda-forge/noarch    82%[+] 2.1s
# conda-forge/linux-64  47%
# conda-forge/noarch    90%[+] 2.2s
# conda-forge/linux-64  51%
# conda-forge/noarch    98%conda-forge/noarch
# [+] 2.3s
# conda-forge/linux-64  54%[+] 2.4s
# conda-forge/linux-64  62%[+] 2.5s
# conda-forge/linux-64  68%[+] 2.6s
# conda-forge/linux-64  75%[+] 2.7s
# conda-forge/linux-64  80%[+] 2.8s
# conda-forge/linux-64  87%[+] 2.9s
# conda-forge/linux-64  92%[+] 3.0s
# conda-forge/linux-64  97%conda-forge/linux-64
#
# Pinned packages:
#
#   - python=3.13
#
# Pinned packages:
#
#   - python_abi[version="=3.13",build="*cp313*"]
#
# Pinned packages:
#
#   - cuda-version*.*
#
# Pinned packages:
#
#   - python=3.13

# %%
# %run /content/pygmt-map-lab/examples/02_region_map_section.py
